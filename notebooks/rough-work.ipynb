# %% [markdown]
# ### Building Smaller Dataset for Pytests in CI/CD
#
# Dataset Folder heirachy for working on Local, CI/CD branches tests , CI/CD Merges to Production branch
#
# /dataset
#   - dev/  //size : as per local dev
#     - raw/
#     - processed/
#   - pytest-micro-data/  //size: 300 // data used to test Pipeline in normal branches in Ci/Cd or in Normal Test ()
#     - raw/
#     - processed/
#   - golden-data    // data to evaluate new models and store processed data , used when merging a new branch to Master/prod in Ci/Cd
#     - raw/
#     - processed/

# %%
import pandas as pd

# %%
df=pd.read_csv('../dataset/heart_disease_risk_2026.csv')
df.head()
# Out:
#    patient_id  age     sex  resting_bp_systolic  resting_bp_diastolic  \
# 0           1   44    Male                  117                    74
# 1           2   57    Male                  139                    94
# 2           3   29    Male                  128                    78
# 3           4   72    Male                  132                    86
# 4           5   62  Female                  116                    75
#
#    cholesterol_total  hdl  ldl  triglycerides  fasting_blood_sugar  ...  \
# 0                193   57  106            119                  112  ...
# 1                185   69  110             35                  114  ...
# 2                197   52  108            157                   95  ...
# 3                197   59  104            143                   92  ...
# 4                154   65   75            104                  135  ...
#
#    family_history  smoker_status  alcohol_units_per_week  \
# ...

# %%
micro_df = df[:300]

# %%
micro_df.to_csv("../dataset/pytest-micro-data/raw/heart_disease_risk_2026_300.csv")

# %%
import requests

def verify_health():
    try:
        res = requests.get("http://localhost:8000/")
        if res.status_code==200:
            data = res.json()
            assert data['success']
        else:
            print("Failed",res.status_code)
    except requests.exceptions.RequestException as e:
        print("Error Occuured:",e)

# %%
verify_health()
